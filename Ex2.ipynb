# %%
# Example data frame plot

import numpy as np
import pandas as pd

df1 = pd.DataFrame(np.random.rand(10, 4), columns=('col1', 'col2', 'col3', 'col4'))
print(df1)
# Out:
#        col1      col2      col3      col4
# 0  0.034204  0.679334  0.093039  0.130113
# 1  0.860387  0.461638  0.218792  0.467148
# 2  0.691450  0.398871  0.861154  0.496005
# 3  0.952466  0.761687  0.642843  0.164620
# 4  0.784329  0.121810  0.879623  0.667681
# 5  0.069370  0.456814  0.451949  0.377889
# 6  0.811086  0.718628  0.651565  0.509621
# 7  0.427300  0.030181  0.006674  0.513386
# 8  0.265420  0.735969  0.233740  0.512816
# 9  0.421772  0.817088  0.711616  0.157930

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(subplots=True, figsize=(8,8))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df1.plot(kind='bar')
# Out:
# <Axes: >

# %%
df1.plot(kind='line')
# Out:
# <Axes: >

# %%
df1.plot(kind='pie', y='col3')
# Out:
# <Axes: ylabel='col3'>

# %%
df1.plot(kind='box')
# Out:
# <Axes: >

# %%
df1.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df1.plot(kind='area')
# Out:
# <Axes: >

# %%
df1.plot(kind='scatter', x=2, y='col2')
# Out:
# <Axes: xlabel='col3', ylabel='col2'>

# %%
df1.plot(kind='hexbin', x='col2', y='col1', gridsize=6)
# Out:
# <Axes: xlabel='col2', ylabel='col1'>
